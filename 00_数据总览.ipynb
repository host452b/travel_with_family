# %% [markdown]
# # 🌍 Travel With Family — 数据总览
#
# **1,072 条 · 50+ 国家 · 34 列 · 机构数据校准**
#
# > 评分：<span style='background:rgba(220,60,60,0.35);padding:2px 6px'>低</span>→<span style='background:rgba(40,200,100,0.35);padding:2px 6px'>高</span>　方差：<span style='background:rgba(40,200,100,0.35);padding:2px 6px'>稳定可信</span>→<span style='background:rgba(220,60,60,0.35);padding:2px 6px'>两极分化</span>

# %%
# 总览
# Out:
# <table>
# <tr><th>数据集</th><th>记录</th><th>覆盖</th></tr>
# <tr><td>🇨🇳 china_5a_scenic_spots</td><td><b>358</b></td><td>中国 31 省 5A 景区</td></tr>
# <tr><td>🌏 asia_oceania_scenic_spots</td><td><b>340</b></td><td>亚洲/大洋洲 41+ 国</td></tr>
# <tr><td>🇪🇺 europe_scenic_spots</td><td><b>173</b></td><td>欧洲 40 国</td></tr>
# <tr><td>🎢 china_resorts_parks</td><td><b>88</b></td><td>国内乐园/度假</td></tr>
# <tr><td>🏖️ asia_resorts_parks</td><td><b>63</b></td><td>亚洲乐园/度假</td></tr>
# <tr><td>🏰 europe_global_resorts_parks</td><td><b>50</b></td><td>欧洲/全球乐园</td></tr>
# <tr style="font-weight:bold;background:#f0f0f0"><td>合计</td><td>1,072</td><td>50+ 国家</td></tr>
# </table>

# %% [markdown]
# ## 新增列说明
#
# | 列 | 含义 | 如何理解 |
# |----|------|---------|
# | **口碑方差** | 0-5，评价一致性 | **低 (0-1.5)**：评价稳定一致，去了基本不会失望 |
# | | | **中 (1.5-2.5)**：多数人满意，少数有不同意见 |
# | | | **高 (2.5-5)**：评价两极分化，可能很好也可能很差，取决于运气/时间/期望 |
# | **备注** | 一句话描述 | 快速了解这个地方是什么 |
#
# ## 数据来源
#
# | 来源 | 用途 |
# |------|------|
# | 文化和旅游部统计公报 | 中国景区客流量、收入 |
# | 中国旅游研究院满意度调查 | 60城游客满意度指数 |
# | 携程/马蜂窝/大众点评 | 口碑评分、亲子/老人标签 |
# | TripAdvisor / Google Maps | 国际景点评分 |
# | Global Peace Index (IEP) | 163国安全指数 |
# | Numbeo Safety Index | 城市级治安数据 |
# | WEF 旅游竞争力指数 | 119国基础设施/政策评估 |
# | UNWTO 世界旅游数据 | 国际客流、旅游收入 |
# | Eurostat | 欧盟旅游统计 |
# | Mastercard 跨境旅游报告 | 消费预算校准 |
